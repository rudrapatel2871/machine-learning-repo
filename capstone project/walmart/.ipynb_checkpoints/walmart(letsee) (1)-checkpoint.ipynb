# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data1 = pd.read_csv(r'C:\Users\HP\Downloads\Walmart (2).csv')
data1.set_index('Date', inplace=True)
# There are about 45 different stores in this dataset. Lets select the any store id from 1-45
a= int(input("Enter the store id:"))
store = data1[data1.Store == a]
sales = pd.DataFrame(store.Weekly_Sales.groupby(store.index).sum())
sales.dtypes
# Out:
# Enter the store id:22
# Weekly_Sales    float64
# dtype: object

# %%
sales.head(20)
# Out:
#             Weekly_Sales
# Date
# 01-04-2011     951588.37
# 01-06-2012    1102857.37
# 01-07-2011    1077491.68
# 01-10-2010     905987.17
# 02-03-2012     974866.65
# 02-04-2010    1177340.99
# 02-07-2010    1120259.71
# 02-09-2011     912762.76
# 02-12-2011    1167621.14
# 03-02-2012     958487.75
# 03-06-2011    1125169.92
# 03-08-2012    1007257.83
# 03-09-2010    1074535.88
# 03-12-2010    1230514.58
# 04-02-2011     946060.98
# 04-03-2011     997353.15
# 04-05-2012    1005083.31
# 04-06-2010    1095539.13
# 04-11-2011    1106575.59
# 05-02-2010    1033017.37

# %%
#remove date from index to change its dtype because it clearly isnt acceptable.
sales.reset_index(inplace = True)
#converting 'date' column to a datetime type
sales['Date'] = pd.to_datetime(sales['Date'])
# resetting date back to the index
sales.set_index('Date',inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '13-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '13-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '13-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '13-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '13-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '14-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '14-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '14-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '14-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '15-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '15-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '15-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '15-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '16-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '16-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '16-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '16-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '16-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '17-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '17-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '17-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '17-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '17-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '18-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '18-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '18-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '18-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '18-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '19-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '19-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '19-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '19-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '19-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '20-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '20-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '20-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '20-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '20-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '21-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '21-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '21-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '21-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '22-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '22-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '22-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '22-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '23-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '23-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '23-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '23-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '23-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '24-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '24-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '24-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '24-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '24-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '25-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '25-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '25-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '25-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '25-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '26-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '26-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '26-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '26-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '26-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '27-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '27-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '27-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '27-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '27-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '28-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '28-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '28-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '28-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '29-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '29-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '29-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '29-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '30-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '30-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '30-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '30-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '30-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '31-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\1042104552.py:4: UserWarning: Parsing '31-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales['Date'] = pd.to_datetime(sales['Date'])

# %%
sales.Weekly_Sales.plot(figsize=(10,6), title= 'Weekly Sales of a Store', fontsize=14, color = 'blue')
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

decomposition = seasonal_decompose(sales.Weekly_Sales, period=12)  
fig = plt.figure()  
fig = decomposition.plot()  
fig.set_size_inches(12, 10)
plt.show()

# %%
#lets compare the 2012 data of two stores
# Lets take store 5 data for analysis
store5 = data1[data1.Store == 5]
# there are about 45 different stores in this dataset.

sales5 = pd.DataFrame(store5.Weekly_Sales.groupby(store5.index).sum())
sales5.dtypes
# Grouped weekly sales by store 6

#remove date from index to change its dtype because it clearly isnt acceptable.
sales5.reset_index(inplace = True)

#converting 'date' column to a datetime type
sales5['Date'] = pd.to_datetime(sales5['Date'])
# resetting date back to the index
sales5.set_index('Date',inplace = True)
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '13-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '13-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '13-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '13-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '13-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '14-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '14-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '14-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '14-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '15-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '15-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '15-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '15-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '16-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '16-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '16-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '16-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '16-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '17-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '17-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '17-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '17-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '17-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '18-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '18-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '18-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '18-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '18-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '19-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '19-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '19-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '19-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '19-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '20-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '20-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '20-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '20-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '20-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '21-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '21-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '21-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '21-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '22-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '22-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '22-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '22-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '23-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '23-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '23-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '23-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '23-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '24-02-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '24-06-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '24-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '24-09-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '24-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '25-02-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '25-03-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '25-05-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '25-06-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '25-11-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '26-02-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '26-03-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '26-08-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '26-10-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '26-11-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '27-01-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '27-04-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '27-05-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '27-07-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '27-08-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '28-01-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '28-05-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '28-09-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '28-10-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '29-04-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '29-06-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '29-07-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '29-10-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '30-03-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '30-04-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '30-07-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '30-09-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '30-12-2011' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '31-08-2012' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\337423408.py:14: UserWarning: Parsing '31-12-2010' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   sales5['Date'] = pd.to_datetime(sales5['Date'])

# %%
y1=sales.Weekly_Sales
y2=sales5.Weekly_Sales

# %%
y1['2012'].plot(figsize=(15, 6),legend=True, color = 'chocolate')
y2['2012'].plot(figsize=(15, 6), legend=True, color = 'turquoise')
plt.ylabel('Weekly Sales')
plt.title('Store4 vs Store5 on 2012', fontsize = '16')
plt.show()

# %%
# Clearly we can see the irregularities

# %%
# Define the p, d and q parameters to take any value between 0 and 2
p = d = q = range(0, 5)
import itertools
# Generate all different combinations of p, d and q triplets
pdq = list(itertools.product(p, d, q))

# Generate all different combinations of seasonal p, d and q triplets
seasonal_pdq = [(x[0], x[1], x[2], 52) for x in list(itertools.product(p, d, q))]

# %%
import statsmodels.api as sm

mod = sm.tsa.statespace.SARIMAX(y1,
                                order=(4, 4, 3),
                                seasonal_order=(1, 1, 0, 52),   #enforce_stationarity=False,
                                enforce_invertibility=False)

results = mod.fit()

print(results.summary().tables[1])
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:471: ValueWarning: A date index has been provided, but it is not monotonic and so will be ignored when e.g. forecasting.
#   self._init_dates(dates, freq)
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:997: UserWarning: Non-stationary starting seasonal autoregressive Using zeros as starting parameters.
#   warn('Non-stationary starting seasonal autoregressive'
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -1.1622      0.263     -4.417      0.000      -1.678      -0.646
# ar.L2         -1.0925      0.380     -2.876      0.004      -1.837      -0.348
# ar.L3         -1.0430      0.290     -3.600      0.000      -1.611      -0.475
# ar.L4         -0.7561      0.184     -4.099      0.000      -1.118      -0.395
# ma.L1         -2.2332      0.292     -7.654      0.000      -2.805      -1.661
# ma.L2          1.4828      0.572      2.594      0.009       0.363       2.603
# ma.L3         -0.2465      0.298     -0.827      0.408      -0.831       0.337
# ar.S.L52      -0.6028      0.182     -3.320      0.001      -0.959      -0.247
# sigma2      1.142e+11   3.48e-12   3.28e+22      0.000    1.14e+11    1.14e+11
# ==============================================================================

# %%
plt.style.use('seaborn-pastel')
results.plot_diagnostics(figsize=(15, 12))
plt.show()

# %%
pred = results.get_prediction(start=pd.to_datetime('2012-07-27'), dynamic=False)
pred_ci = pred.conf_int()

# %%
ax = y1['2010':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast', alpha=.7)

ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)

ax.set_xlabel('Time Period')
ax.set_ylabel('Sales')
plt.legend()

plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\2689329424.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   ax = y1['2010':].plot(label='observed')

# %%
y_forecasted = pred.predicted_mean
y_truth = y1['2012-7-27':]

# Compute the mean square error
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Mean Squared Error of our forecasts is {}'.format(round(mse, 2)))
# Out:
# The Mean Squared Error of our forecasts is 28636274043.18

# %%
pred_dynamic = results.get_prediction(start=pd.to_datetime('2012-7-27'), dynamic=True, full_results=True)
pred_dynamic_ci = pred_dynamic.conf_int()

# %%
ax = y1['2010':].plot(label='observed', figsize=(12, 8))
pred_dynamic.predicted_mean.plot(label='Dynamic Forecast', ax=ax)

ax.fill_between(pred_dynamic_ci.index,
                pred_dynamic_ci.iloc[:, 0],
                pred_dynamic_ci.iloc[:, 1], color='k', alpha=.25)

ax.fill_betweenx(ax.get_ylim(), pd.to_datetime('2012-7-26'), y1.index[-1],
                 alpha=.1, zorder=-1)

ax.set_xlabel('Time Period')
ax.set_ylabel('Sales')

plt.legend()
plt.show()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_8504\4127785946.py:1: FutureWarning: Value based partial slicing on non-monotonic DatetimeIndexes with non-existing keys is deprecated and will raise a KeyError in a future Version.
#   ax = y1['2010':].plot(label='observed', figsize=(12, 8))

# %%
import numpy as np
# Extract the predicted and true values of our time series
y_forecasted = pred_dynamic.predicted_mean
print(y_forecasted)
# Out:
# Date
# 2012-07-27    1.205017e+06
# 2010-08-27    1.174084e+06
# 2011-01-28    5.742142e+05
# 2010-05-28    9.777730e+05
# 2012-09-28    8.650936e+05
# 2011-10-28    1.139981e+06
# 2011-04-29    8.276909e+05
# 2012-06-29    3.782356e+05
# 2011-07-29    7.410754e+05
# 2010-10-29    6.647317e+05
# 2012-03-30    6.252202e+05
# 2010-04-30    4.688193e+05
# 2010-07-30    3.216021e+05
# 2011-09-30    4.587662e+05
# 2011-12-30    3.399325e+05
# 2012-08-31    2.798574e+05
# 2010-12-31    1.031730e+05
# Name: predicted_mean, dtype: float64

# %%
y_truth = y1['2012-7-27':]

print(y_truth)
# Out:
# Date
# 2012-08-06    1061134.37
# 2012-09-03     991127.01
# 2012-10-02    1034448.07
# 2012-10-08     973812.79
# 2012-11-05     997868.63
# 2012-12-10    1004039.84
# 2012-09-14     918049.28
# 2012-08-17     981273.26
# 2012-10-19     978027.95
# 2012-09-21     921612.53
# 2012-08-24    1060906.75
# 2012-10-26    1094422.69
# 2012-07-27     925731.21
# 2012-09-28     976479.51
# 2012-08-31    1022270.86
# Name: Weekly_Sales, dtype: float64

# %%
# Compute the Root mean square error
rmse = np.sqrt(((y_forecasted - y_truth) ** 2).mean())
print('The Root Mean Squared Error of our forecasts is {}'.format(round(rmse, 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 462451.92

# %%
Residual= y_forecasted - y_truth
print("Residual for Store1",np.abs(Residual).sum())
# Out:
# Residual for Store1 1133085.4740104112

# %%
# Get forecast 12 weeks ahead in future
pred_uc = results.get_forecast(steps=12)

print(pred_uc)
# Out:
# <statsmodels.tsa.statespace.mlemodel.PredictionResultsWrapper object at 0x000001DD579BB9D0>
# C:\Users\HP\anaconda3\lib\site-packages\statsmodels\tsa\base\tsa_model.py:834: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   return get_prediction_index(

# %%
# Get confidence intervals of forecasts
pred_ci = pred_uc.conf_int()

# %%
ax = y1.plot(label='observed', figsize=(12, 8))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Time Period')
ax.set_ylabel('Sales')

plt.legend()
plt.show()
