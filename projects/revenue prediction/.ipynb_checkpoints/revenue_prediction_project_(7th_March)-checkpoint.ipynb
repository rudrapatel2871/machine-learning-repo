# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('revenue_prediction (2).csv')

# %%
df
# Out:
#      Id                          Name Franchise       Category       City  \
# 0   101            HungryHowie'sPizza       Yes        Mexican  Bengaluru
# 1   102          CharleysPhillySteaks        No    Varied Menu   Gurugram
# 2   103                        Chuy's       Yes        Chicken       Pune
# 3   104                   O'Charley's       Yes  Italian/Pizza     Mumbai
# 4   105                 PolloTropical       Yes          Pizza      Noida
# ..  ...                           ...       ...            ...        ...
# 95  196              Wetzel'sPretzels        No  Italian/Pizza  Bengaluru
# 96  197  LaMadeleineCountryFrenchCafe       Yes    Varied Menu  Bengaluru
# 97  198                    Giordano's       Yes    Varied Menu   Gurugram
# 98  199     IslandsFineBurgers&Drinks       Yes     Sports Bar       Pune
# 99  200           Mimi'sBistro&Bakery        No            BBQ     Mumbai
#
#     No_Of_Item  Order_Placed  Revenue
# 0           55           5.5  5953753
# ...

# %%
df.isnull().sum()
# Out:
# Id              0
# Name            0
# Franchise       0
# Category        0
# City            0
# No_Of_Item      0
# Order_Placed    0
# Revenue         0
# dtype: int64

# %%
df=df.drop(columns=['Id','Name','Franchise','Category','City','No_Of_Item'])

# %%
df
# Out:
#     Order_Placed  Revenue
# 0            5.5  5953753
# 1            6.8  7223131
# 2            1.9  2555379
# 3            2.5  2175511
# 4            4.2  4816715
# ..           ...      ...
# 95           1.1  1270499
# 96           6.3  6412623
# 97           6.2  6694797
# 98           2.1  2344689
# 99           4.4  4567678
#
# [100 rows x 2 columns]

# %%
df.shape
# Out:
# (100, 2)

# %%
x=df.iloc[:,:-1].values
y=df.iloc[:,-1].values

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=23)

# %%
x_train
# Out:
# array([[ 7.2],
#        [ 4.6],
#        [ 4.8],
#        [ 5. ],
#        [ 1.5],
#        [ 4.2],
#        [ 5.4],
#        [ 4.9],
#        [ 3.9],
#        [ 2.1],
#        [ 6.2],
#        [ 2.8],
#        [ 4.3],
#        [ 3. ],
#        [ 5.3],
#        [ 3.5],
#        [ 5.2],
#        [ 4.2],
#        [ 7.7],
#        [10.8],
#        [ 5.1],
#        [ 3.9],
#        [ 1.6],
#        [ 1.9],
#        [ 4.1],
#        [ 4. ],
#        [ 4.4],
#        [ 1.9],
#        [ 6.1],
#        [ 5.5],
#        [ 1.8],
#        [ 2.9],
#        [ 1.1],
#        [ 5.3],
#        [ 3.8],
#        [ 4.7],
#        [ 2.1],
#        [ 3.1],
#        [ 3.6],
#        [ 4. ],
#        [ 3.6],
#        [ 1.9],
#        [ 3.3],
#        [ 6.3],
#        [ 2.9],
#        [ 3.8],
#        [ 2.6],
#        [ 6.8],
#        [ 1.6],
#        [ 2.8],
#        [ 3.1],
#        [ 6.5],
#        [ 3.4],
#        [ 2.2],
#        [ 1.9],
#        [ 3.1],
#        [ 5.1],
#        [ 4.4],
# ...

# %%
x_test
# Out:
# array([[2.1],
#        [3.5],
#        [3.6],
#        [3.6],
#        [1.7],
#        [2.6],
#        [2.5],
#        [6.8],
#        [5.4],
#        [8.1],
#        [2.4],
#        [8.8],
#        [4. ],
#        [5.8],
#        [2.1],
#        [3.3],
#        [5.3],
#        [3.8],
#        [4.8],
#        [3.5]])

# %%
y_train
# Out:
# array([ 7495092,  7705945,  5152497,  3861370,  1619683,  4816715,
#         5595267,  4517319,  4066618,  2344689,  6694797,  1999068,
#         6491607,  3164972,  6135276,  3871344,  4937526,  4350573,
#         7865428, 19696939,  5500818,  4250553,  1763231,  2156098,
#         4250758,  4100886,  4567678,  2025297,  6313221,  5953753,
#         1099097,  2408199,  1270499,  5461700,  4956086,  5107746,
#         2390534,  3261924,  3903884,  4264176,  3945135,  2555379,
#         3410878,  6412623,  3004429,  3982767,  2732645,  7223131,
#         1756069,  3028267,  3918918,  6782425,  3600467,  2371202,
#         1521934,  3258837,  5286212,  4554237,  7201784,   849870,
#         3351383,  2551252,  3452382, 16549064,  1882131,  8630682,
#         2234634,  3752885,  5966635,  3273041,  2778621,  3426169,
#         3818055,  2083447,  4590423,  2358644,  4651866,  3347767,
#         6836483,  5966193], dtype=int64)

# %%
y_test
# Out:
# array([2967425, 3727364, 3807496, 3836721, 1904842, 2740687, 2175511,
#        6941173, 5025735, 7513524, 2525375, 7904084, 4136425, 5906596,
#        2364478, 2447890, 4544227, 4052733, 4952255, 3753720], dtype=int64)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
y_pred
# Out:
# array([ 1945842.75096428,  3735954.74900125,  3863819.89171818,
#         3863819.89171818,  1434382.18009658,  2585168.46454891,
#         2457303.32183199,  7955504.45865982,  6165392.46062285,
#         9617751.31397986,  2329438.17911506, 10512807.31299835,
#         4375280.46258588,  6676853.03149056,  1945842.75096428,
#         3480224.4635674 ,  6037527.31790592,  4119550.17715203,
#         5398201.60432129,  3735954.74900125])

# %%
plt.scatter(x_train,y_train,color='blue')
plt.plot(x_train,lr.predict(x_train),color='green')
plt.title('Best Fit Line for x_train')
plt.xlabel('Orders on Average')
plt.ylabel('Revenue Generated')
# Out:
# Text(0, 0.5, 'Revenue Generated')

# %%
from sklearn.metrics import r2_score

# %%
score=r2_score(y_pred,y_test)

# %%
score
# Out:
# 0.8429778249656114

# %%
# HW Create models for DecisionTreeRegressor and RandomForestRegressor and check the accuracies

# %%
## decision tree regressor model 
from sklearn.tree import DecisionTreeRegressor

# %%
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV

# %%
dt_regressor = DecisionTreeRegressor(random_state = 0)
dt_regressor.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# r2 score 
y_pred_train = dt_regressor.predict(x_train)
r2_score(y_train, y_pred_train)
# Out:
# 0.9881177845814085

# %%
# tree vizualization
from sklearn.tree import plot_tree

# %%
fig = plt.figure(figsize=(30,30))
_ = tree.plot_tree(dt_regressor, feature_names=['Order_Placed'], filled=True,fontsize=12)

# %%
## random forest regressor 
from sklearn.metrics import r2_score
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
rf_regressor = RandomForestRegressor(n_estimators = 10, random_state = 0)
rf_regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(n_estimators=10, random_state=0)

# %%
# training accuracy
y_pred_train = rf_regressor.predict(x_train)
r2_score(y_train, y_pred_train)
# Out:
# 0.979520744841288

# %%
#Testing Accuracy
y_pred = rf_regressor.predict(x_test)
r2_score(y_test, y_pred)
# Out:
# 0.900259705459507
